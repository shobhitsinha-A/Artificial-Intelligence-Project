# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('/content/drive/MyDrive/ph2_resized/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('/content/drive/MyDrive/ph2_resized/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train.shape
# Out:
# (200, 224, 224, 3)

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped]).astype(np.float32)
y_train_full = np.concatenate([y_train, y_rotated, y_flipped]).astype(np.float32)

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_data_format() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.image_data_format() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 1 epoch

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 224, 224, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d (SpatialDropo (None, 224, 224, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 112, 112, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 112, 112, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 56, 56, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 28, 28, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 256)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 14, 14, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)    0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 1024)   4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 7, 7, 1024)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 14, 14, 1024) 0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1536) 0           up_sampling2d[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  2359808     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 14, 14, 512)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 512)  0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  590080      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 28, 28, 256)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 56, 56, 256)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 56, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 56, 56, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 112, 112, 128 0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 112, 112, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 112, 112, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 64) 36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 112, 112, 64) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 224, 224, 64) 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 224, 224, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 224, 224, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 224, 224, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 224, 224, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 224, 224, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 224, 224, 1)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 224, 224)     0           activation_22[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# 20/20 [==============================] - 49s 451ms/step - loss: 0.2313 - iou: 0.7687 - dice_coe: 0.5430 - precision: 0.5439 - recall: 0.7192 - accuracy: 0.6814 - val_loss: 0.4748 - val_iou: 0.5252 - val_dice_coe: 0.4753 - val_precision: 0.3133 - val_recall: 1.0000 - val_accuracy: 0.3133

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
if K.image_data_format() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test.astype(np.float32), y_test.astype(np.float32), batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 20/20 [==============================] - 3s 120ms/step - loss: 0.4682 - iou: 0.5318 - dice_coe: 0.4842 - precision: 0.3228 - recall: 1.0000 - accuracy: 0.3228
# ________________________
# IOU:       |   53.26  |
# Dice Coef: |   48.53  |
# Precision: |   32.39  |
# Recall:    |   100.00  |
# Accuracy:  |   32.39  |
# Loss:      |   46.74  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 3s 1s/step - loss: 0.4744 - iou: 0.5256 - dice_coe: 0.4780 - precision: 0.3158 - recall: 1.0000 - accuracy: 0.3158
# ________________________
# IOU:       |   52.56  |
# Dice Coef: |   47.80  |
# Precision: |   31.58  |
# Recall:    |   100.00  |
# Accuracy:  |   31.58  |
# Loss:      |   47.44  |
# ________________________
#
# -------------On validation Set---------------------
#
# 5/5 [==============================] - 1s 118ms/step - loss: 0.4748 - iou: 0.5252 - dice_coe: 0.4753 - precision: 0.3133 - recall: 1.0000 - accuracy: 0.3133
# ________________________
# IOU:       |   52.52  |
# Dice Coef: |   47.53  |
# Precision: |   31.33  |
# Recall:    |   100.00  |
# Accuracy:  |   31.33  |
# Loss:      |   47.48  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# Model: "UNET_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 224, 224, 32) 128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 224, 224, 32) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 9248        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_22 (SpatialDr (None, 224, 224, 32) 0           activation_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 112, 112, 64) 256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 112, 112, 64) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 112, 112, 64) 0           activation_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 56, 56, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 56, 56, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  147584      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 56, 56, 128)  0           activation_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 28, 28, 256)  1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 28, 28, 256)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  590080      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 28, 28, 256)  0           activation_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 14, 14, 512)  2048        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 512)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  2359808     activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 14, 14, 512)  0           activation_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 7, 7, 1024)   4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 7, 7, 1024)   0           activation_57[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_10[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 14, 14, 512)  2048        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 14, 14, 512)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  2359808     activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 14, 14, 512)  0           activation_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 28, 28, 256)  1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 28, 28, 256)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  590080      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 28, 28, 256)  0           activation_61[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 56, 56, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 56, 56, 128)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  147584      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 56, 56, 128)  0           activation_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 112, 112, 64) 256         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 112, 112, 64) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 36928       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 112, 112, 64) 0           activation_65[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 224, 224, 32) 128         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 224, 224, 32) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 9248        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 224, 224, 32) 0           activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 1)  0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 224, 224)     0           activation_68[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 12s 441ms/step - loss: 0.2075 - iou: 0.7925 - dice_coe: 0.5033 - precision: 0.6008 - recall: 0.5616 - accuracy: 0.7471 - val_loss: 0.4748 - val_iou: 0.5252 - val_dice_coe: 0.4753 - val_precision: 0.3133 - val_recall: 1.0000 - val_accuracy: 0.3133
# Epoch 2/100
# 20/20 [==============================] - 8s 416ms/step - loss: 0.1310 - iou: 0.8690 - dice_coe: 0.6646 - precision: 0.7697 - recall: 0.7680 - accuracy: 0.8486 - val_loss: 0.4748 - val_iou: 0.5252 - val_dice_coe: 0.4753 - val_precision: 0.3133 - val_recall: 1.0000 - val_accuracy: 0.3133
# Epoch 3/100
# 20/20 [==============================] - 8s 418ms/step - loss: 0.0969 - iou: 0.9031 - dice_coe: 0.7484 - precision: 0.8826 - recall: 0.7993 - accuracy: 0.8912 - val_loss: 0.4260 - val_iou: 0.5740 - val_dice_coe: 0.5012 - val_precision: 0.3406 - val_recall: 0.9636 - val_accuracy: 0.4044
# Epoch 4/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.1041 - iou: 0.8959 - dice_coe: 0.7538 - precision: 0.8545 - recall: 0.8032 - accuracy: 0.8768 - val_loss: 0.4478 - val_iou: 0.5522 - val_dice_coe: 0.4887 - val_precision: 0.3267 - val_recall: 0.9851 - val_accuracy: 0.3593
# Epoch 5/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.0865 - iou: 0.9135 - dice_coe: 0.7765 - precision: 0.9171 - recall: 0.7903 - accuracy: 0.9050 - val_loss: 0.4746 - val_iou: 0.5254 - val_dice_coe: 0.4752 - val_precision: 0.3133 - val_recall: 0.9992 - val_accuracy: 0.3135
# Epoch 6/100
# 20/20 [==============================] - 8s 426ms/step - loss: 0.0876 - iou: 0.9124 - dice_coe: 0.7864 - precision: 0.9031 - recall: 0.8014 - accuracy: 0.9000 - val_loss: 0.3631 - val_iou: 0.6369 - val_dice_coe: 0.5170 - val_precision: 0.3826 - val_recall: 0.8126 - val_accuracy: 0.5294
# Epoch 7/100
# 20/20 [==============================] - 9s 429ms/step - loss: 0.0808 - iou: 0.9192 - dice_coe: 0.7851 - precision: 0.8553 - recall: 0.8443 - accuracy: 0.9094 - val_loss: 0.1921 - val_iou: 0.8079 - val_dice_coe: 0.6378 - val_precision: 0.7665 - val_recall: 0.5515 - val_accuracy: 0.8101
# Epoch 8/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.0929 - iou: 0.9071 - dice_coe: 0.7803 - precision: 0.8445 - recall: 0.8201 - accuracy: 0.8888 - val_loss: 0.0991 - val_iou: 0.9009 - val_dice_coe: 0.8016 - val_precision: 0.8408 - val_recall: 0.8041 - val_accuracy: 0.8898
# Epoch 9/100
# 20/20 [==============================] - 9s 433ms/step - loss: 0.0825 - iou: 0.9175 - dice_coe: 0.8122 - precision: 0.8874 - recall: 0.8366 - accuracy: 0.9053 - val_loss: 0.3641 - val_iou: 0.6359 - val_dice_coe: 0.5136 - val_precision: 0.3690 - val_recall: 0.8730 - val_accuracy: 0.4933
# Epoch 10/100
# 20/20 [==============================] - 9s 435ms/step - loss: 0.0847 - iou: 0.9153 - dice_coe: 0.7817 - precision: 0.8717 - recall: 0.7964 - accuracy: 0.9009 - val_loss: 0.0955 - val_iou: 0.9045 - val_dice_coe: 0.7921 - val_precision: 0.9439 - val_recall: 0.7066 - val_accuracy: 0.8951
# Epoch 11/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.0709 - iou: 0.9291 - dice_coe: 0.8211 - precision: 0.8969 - recall: 0.8564 - accuracy: 0.9228 - val_loss: 0.1521 - val_iou: 0.8479 - val_dice_coe: 0.7140 - val_precision: 0.8149 - val_recall: 0.6612 - val_accuracy: 0.8422
# Epoch 12/100
# 20/20 [==============================] - 9s 441ms/step - loss: 0.0755 - iou: 0.9245 - dice_coe: 0.8179 - precision: 0.8804 - recall: 0.8552 - accuracy: 0.9134 - val_loss: 0.0687 - val_iou: 0.9313 - val_dice_coe: 0.8650 - val_precision: 0.9017 - val_recall: 0.8566 - val_accuracy: 0.9246
# Epoch 13/100
# 20/20 [==============================] - 9s 442ms/step - loss: 0.0720 - iou: 0.9280 - dice_coe: 0.8278 - precision: 0.9113 - recall: 0.8404 - accuracy: 0.9168 - val_loss: 0.0777 - val_iou: 0.9223 - val_dice_coe: 0.8407 - val_precision: 0.9429 - val_recall: 0.7737 - val_accuracy: 0.9125
# Epoch 14/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0765 - iou: 0.9235 - dice_coe: 0.8188 - precision: 0.9244 - recall: 0.8099 - accuracy: 0.9095 - val_loss: 0.1155 - val_iou: 0.8845 - val_dice_coe: 0.8046 - val_precision: 0.7939 - val_recall: 0.8463 - val_accuracy: 0.8808
# Epoch 15/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.0700 - iou: 0.9300 - dice_coe: 0.8344 - precision: 0.9141 - recall: 0.8343 - accuracy: 0.9187 - val_loss: 0.0809 - val_iou: 0.9191 - val_dice_coe: 0.8426 - val_precision: 0.9070 - val_recall: 0.8011 - val_accuracy: 0.9107
# Epoch 16/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.0671 - iou: 0.9329 - dice_coe: 0.8379 - precision: 0.9290 - recall: 0.8400 - accuracy: 0.9230 - val_loss: 0.0669 - val_iou: 0.9331 - val_dice_coe: 0.8642 - val_precision: 0.9499 - val_recall: 0.8071 - val_accuracy: 0.9261
# Epoch 17/100
# 20/20 [==============================] - 9s 435ms/step - loss: 0.0651 - iou: 0.9349 - dice_coe: 0.8445 - precision: 0.9148 - recall: 0.8444 - accuracy: 0.9228 - val_loss: 0.0585 - val_iou: 0.9415 - val_dice_coe: 0.8830 - val_precision: 0.9163 - val_recall: 0.8782 - val_accuracy: 0.9351
# Epoch 18/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.0578 - iou: 0.9422 - dice_coe: 0.8560 - precision: 0.9091 - recall: 0.8916 - accuracy: 0.9366 - val_loss: 0.1898 - val_iou: 0.8102 - val_dice_coe: 0.7208 - val_precision: 0.5730 - val_recall: 0.9850 - val_accuracy: 0.7662
# Epoch 19/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0753 - iou: 0.9247 - dice_coe: 0.8279 - precision: 0.8941 - recall: 0.8426 - accuracy: 0.9130 - val_loss: 0.0794 - val_iou: 0.9206 - val_dice_coe: 0.8534 - val_precision: 0.9121 - val_recall: 0.8103 - val_accuracy: 0.9167
# Epoch 20/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0613 - iou: 0.9387 - dice_coe: 0.8545 - precision: 0.9102 - recall: 0.8742 - accuracy: 0.9278 - val_loss: 0.0982 - val_iou: 0.9018 - val_dice_coe: 0.8345 - val_precision: 0.7817 - val_recall: 0.9239 - val_accuracy: 0.8941
# Epoch 21/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0595 - iou: 0.9405 - dice_coe: 0.8398 - precision: 0.9131 - recall: 0.8630 - accuracy: 0.9348 - val_loss: 0.0886 - val_iou: 0.9114 - val_dice_coe: 0.8397 - val_precision: 0.7519 - val_recall: 0.9713 - val_accuracy: 0.8910
# Epoch 22/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0601 - iou: 0.9399 - dice_coe: 0.8520 - precision: 0.8928 - recall: 0.8943 - accuracy: 0.9328 - val_loss: 0.3559 - val_iou: 0.6441 - val_dice_coe: 0.5546 - val_precision: 0.3893 - val_recall: 0.9729 - val_accuracy: 0.5085
# Epoch 23/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0579 - iou: 0.9421 - dice_coe: 0.8570 - precision: 0.9342 - recall: 0.8543 - accuracy: 0.9308 - val_loss: 0.1385 - val_iou: 0.8615 - val_dice_coe: 0.7753 - val_precision: 0.6619 - val_recall: 0.9652 - val_accuracy: 0.8352
# Epoch 24/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0594 - iou: 0.9406 - dice_coe: 0.8579 - precision: 0.9113 - recall: 0.8799 - accuracy: 0.9314 - val_loss: 0.3004 - val_iou: 0.6996 - val_dice_coe: 0.6066 - val_precision: 0.4474 - val_recall: 0.9663 - val_accuracy: 0.6114
# Epoch 25/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0618 - iou: 0.9382 - dice_coe: 0.8573 - precision: 0.9322 - recall: 0.8555 - accuracy: 0.9280 - val_loss: 0.3351 - val_iou: 0.6649 - val_dice_coe: 0.5758 - val_precision: 0.4105 - val_recall: 0.9781 - val_accuracy: 0.5536
# Epoch 26/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0547 - iou: 0.9453 - dice_coe: 0.8727 - precision: 0.9275 - recall: 0.8808 - accuracy: 0.9366 - val_loss: 0.0945 - val_iou: 0.9055 - val_dice_coe: 0.8300 - val_precision: 0.7708 - val_recall: 0.9280 - val_accuracy: 0.8854
# Epoch 27/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0554 - iou: 0.9446 - dice_coe: 0.8664 - precision: 0.9096 - recall: 0.8933 - accuracy: 0.9373 - val_loss: 0.1227 - val_iou: 0.8773 - val_dice_coe: 0.7698 - val_precision: 0.7341 - val_recall: 0.8996 - val_accuracy: 0.8650
# Epoch 28/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0643 - iou: 0.9357 - dice_coe: 0.8559 - precision: 0.9334 - recall: 0.8437 - accuracy: 0.9254 - val_loss: 0.1802 - val_iou: 0.8198 - val_dice_coe: 0.7220 - val_precision: 0.5928 - val_recall: 0.9641 - val_accuracy: 0.7790
# Epoch 29/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0595 - iou: 0.9405 - dice_coe: 0.8598 - precision: 0.9213 - recall: 0.8709 - accuracy: 0.9313 - val_loss: 0.3245 - val_iou: 0.6755 - val_dice_coe: 0.5804 - val_precision: 0.4131 - val_recall: 0.9803 - val_accuracy: 0.5580
# Epoch 30/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0582 - iou: 0.9418 - dice_coe: 0.8637 - precision: 0.9365 - recall: 0.8545 - accuracy: 0.9350 - val_loss: 0.1962 - val_iou: 0.8038 - val_dice_coe: 0.7067 - val_precision: 0.5548 - val_recall: 0.9899 - val_accuracy: 0.7480
# Epoch 31/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0558 - iou: 0.9442 - dice_coe: 0.8675 - precision: 0.9236 - recall: 0.8745 - accuracy: 0.9363 - val_loss: 0.0620 - val_iou: 0.9380 - val_dice_coe: 0.8710 - val_precision: 0.8831 - val_recall: 0.8918 - val_accuracy: 0.9289
# Epoch 32/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0569 - iou: 0.9431 - dice_coe: 0.8563 - precision: 0.9029 - recall: 0.8961 - accuracy: 0.9373 - val_loss: 0.0594 - val_iou: 0.9406 - val_dice_coe: 0.8851 - val_precision: 0.8569 - val_recall: 0.9396 - val_accuracy: 0.9300
# Epoch 33/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8840 - precision: 0.9234 - recall: 0.9116 - accuracy: 0.9475 - val_loss: 0.0541 - val_iou: 0.9459 - val_dice_coe: 0.8920 - val_precision: 0.8531 - val_recall: 0.9583 - val_accuracy: 0.9365
# Epoch 34/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0516 - iou: 0.9484 - dice_coe: 0.8754 - precision: 0.9282 - recall: 0.8867 - accuracy: 0.9418 - val_loss: 0.0465 - val_iou: 0.9535 - val_dice_coe: 0.8970 - val_precision: 0.9548 - val_recall: 0.8714 - val_accuracy: 0.9464
# Epoch 35/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0544 - iou: 0.9456 - dice_coe: 0.8680 - precision: 0.9182 - recall: 0.8897 - accuracy: 0.9389 - val_loss: 0.3142 - val_iou: 0.6858 - val_dice_coe: 0.6038 - val_precision: 0.4325 - val_recall: 0.9957 - val_accuracy: 0.5910
# Epoch 36/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0520 - iou: 0.9480 - dice_coe: 0.8712 - precision: 0.9070 - recall: 0.9060 - accuracy: 0.9402 - val_loss: 0.0536 - val_iou: 0.9464 - val_dice_coe: 0.8918 - val_precision: 0.8639 - val_recall: 0.9523 - val_accuracy: 0.9386
# Epoch 37/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0488 - iou: 0.9512 - dice_coe: 0.8867 - precision: 0.9249 - recall: 0.9096 - accuracy: 0.9456 - val_loss: 0.0805 - val_iou: 0.9195 - val_dice_coe: 0.8526 - val_precision: 0.8077 - val_recall: 0.9373 - val_accuracy: 0.9100
# Epoch 38/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0516 - iou: 0.9484 - dice_coe: 0.8734 - precision: 0.9386 - recall: 0.8718 - accuracy: 0.9412 - val_loss: 0.0815 - val_iou: 0.9185 - val_dice_coe: 0.8396 - val_precision: 0.9226 - val_recall: 0.7969 - val_accuracy: 0.9126
# Epoch 39/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8821 - precision: 0.9252 - recall: 0.9067 - accuracy: 0.9465 - val_loss: 0.0557 - val_iou: 0.9443 - val_dice_coe: 0.8889 - val_precision: 0.8687 - val_recall: 0.9297 - val_accuracy: 0.9334
# Epoch 40/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0604 - iou: 0.9396 - dice_coe: 0.8664 - precision: 0.9077 - recall: 0.8818 - accuracy: 0.9281 - val_loss: 0.2874 - val_iou: 0.7126 - val_dice_coe: 0.6250 - val_precision: 0.4569 - val_recall: 0.9914 - val_accuracy: 0.6281
# Epoch 41/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8807 - precision: 0.9547 - recall: 0.8665 - accuracy: 0.9426 - val_loss: 0.1894 - val_iou: 0.8106 - val_dice_coe: 0.7001 - val_precision: 0.6036 - val_recall: 0.8732 - val_accuracy: 0.7809
# Epoch 42/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0443 - iou: 0.9557 - dice_coe: 0.8968 - precision: 0.9409 - recall: 0.9049 - accuracy: 0.9495 - val_loss: 0.4079 - val_iou: 0.5921 - val_dice_coe: 0.5248 - val_precision: 0.3560 - val_recall: 0.9988 - val_accuracy: 0.4338
# Epoch 43/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0471 - iou: 0.9529 - dice_coe: 0.8883 - precision: 0.9344 - recall: 0.9014 - accuracy: 0.9465 - val_loss: 0.0667 - val_iou: 0.9333 - val_dice_coe: 0.8705 - val_precision: 0.8406 - val_recall: 0.9480 - val_accuracy: 0.9275
# Epoch 44/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8836 - precision: 0.9301 - recall: 0.9050 - accuracy: 0.9489 - val_loss: 0.0627 - val_iou: 0.9373 - val_dice_coe: 0.8753 - val_precision: 0.8375 - val_recall: 0.9449 - val_accuracy: 0.9248
# Epoch 45/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0509 - iou: 0.9491 - dice_coe: 0.8796 - precision: 0.9154 - recall: 0.9013 - accuracy: 0.9421 - val_loss: 0.0417 - val_iou: 0.9583 - val_dice_coe: 0.9104 - val_precision: 0.9474 - val_recall: 0.8910 - val_accuracy: 0.9501
# Epoch 46/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0470 - iou: 0.9530 - dice_coe: 0.8910 - precision: 0.9464 - recall: 0.8887 - accuracy: 0.9440 - val_loss: 0.0907 - val_iou: 0.9093 - val_dice_coe: 0.8334 - val_precision: 0.8727 - val_recall: 0.8205 - val_accuracy: 0.9032
# Epoch 47/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0501 - iou: 0.9499 - dice_coe: 0.8832 - precision: 0.9415 - recall: 0.8859 - accuracy: 0.9422 - val_loss: 0.0531 - val_iou: 0.9469 - val_dice_coe: 0.8942 - val_precision: 0.8652 - val_recall: 0.9585 - val_accuracy: 0.9396
# Epoch 48/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0438 - iou: 0.9562 - dice_coe: 0.8907 - precision: 0.9395 - recall: 0.9049 - accuracy: 0.9506 - val_loss: 0.0609 - val_iou: 0.9391 - val_dice_coe: 0.8704 - val_precision: 0.9217 - val_recall: 0.8565 - val_accuracy: 0.9314
# Epoch 49/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0541 - iou: 0.9459 - dice_coe: 0.8690 - precision: 0.9466 - recall: 0.8560 - accuracy: 0.9365 - val_loss: 0.0456 - val_iou: 0.9544 - val_dice_coe: 0.9009 - val_precision: 0.9468 - val_recall: 0.8778 - val_accuracy: 0.9457
# Epoch 50/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0538 - iou: 0.9462 - dice_coe: 0.8720 - precision: 0.9359 - recall: 0.8683 - accuracy: 0.9368 - val_loss: 0.0688 - val_iou: 0.9312 - val_dice_coe: 0.8691 - val_precision: 0.8361 - val_recall: 0.9206 - val_accuracy: 0.9186
# Epoch 51/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0449 - iou: 0.9551 - dice_coe: 0.8914 - precision: 0.9310 - recall: 0.9012 - accuracy: 0.9485 - val_loss: 0.0863 - val_iou: 0.9137 - val_dice_coe: 0.8454 - val_precision: 0.7655 - val_recall: 0.9794 - val_accuracy: 0.9006
# Epoch 52/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0507 - iou: 0.9493 - dice_coe: 0.8776 - precision: 0.9283 - recall: 0.8856 - accuracy: 0.9402 - val_loss: 0.0565 - val_iou: 0.9435 - val_dice_coe: 0.8759 - val_precision: 0.9430 - val_recall: 0.8300 - val_accuracy: 0.9305
# Epoch 53/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8863 - precision: 0.9381 - recall: 0.8959 - accuracy: 0.9457 - val_loss: 0.0759 - val_iou: 0.9241 - val_dice_coe: 0.8505 - val_precision: 0.8374 - val_recall: 0.9238 - val_accuracy: 0.9192
# Epoch 54/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0475 - iou: 0.9525 - dice_coe: 0.8889 - precision: 0.9362 - recall: 0.8998 - accuracy: 0.9450 - val_loss: 0.0553 - val_iou: 0.9447 - val_dice_coe: 0.8875 - val_precision: 0.8485 - val_recall: 0.9684 - val_accuracy: 0.9359
# Epoch 55/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0447 - iou: 0.9553 - dice_coe: 0.8919 - precision: 0.9284 - recall: 0.9103 - accuracy: 0.9480 - val_loss: 0.0760 - val_iou: 0.9240 - val_dice_coe: 0.8552 - val_precision: 0.8059 - val_recall: 0.9268 - val_accuracy: 0.9068
# Epoch 56/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0547 - iou: 0.9453 - dice_coe: 0.8715 - precision: 0.8899 - recall: 0.9109 - accuracy: 0.9378 - val_loss: 0.0489 - val_iou: 0.9511 - val_dice_coe: 0.8969 - val_precision: 0.9000 - val_recall: 0.9355 - val_accuracy: 0.9451
# Epoch 57/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0521 - iou: 0.9479 - dice_coe: 0.8736 - precision: 0.9112 - recall: 0.9045 - accuracy: 0.9386 - val_loss: 0.0452 - val_iou: 0.9548 - val_dice_coe: 0.8980 - val_precision: 0.9218 - val_recall: 0.9143 - val_accuracy: 0.9473
# Epoch 58/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0418 - iou: 0.9582 - dice_coe: 0.9001 - precision: 0.9365 - recall: 0.9206 - accuracy: 0.9531 - val_loss: 0.0491 - val_iou: 0.9509 - val_dice_coe: 0.8987 - val_precision: 0.9456 - val_recall: 0.8656 - val_accuracy: 0.9420
# Epoch 59/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0424 - iou: 0.9576 - dice_coe: 0.8975 - precision: 0.9352 - recall: 0.9119 - accuracy: 0.9523 - val_loss: 0.0712 - val_iou: 0.9288 - val_dice_coe: 0.8643 - val_precision: 0.8231 - val_recall: 0.9711 - val_accuracy: 0.9254
# Epoch 60/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0487 - iou: 0.9513 - dice_coe: 0.8827 - precision: 0.9141 - recall: 0.9144 - accuracy: 0.9456 - val_loss: 0.1042 - val_iou: 0.8958 - val_dice_coe: 0.7745 - val_precision: 0.9675 - val_recall: 0.6608 - val_accuracy: 0.8868
# Epoch 61/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0518 - iou: 0.9482 - dice_coe: 0.8804 - precision: 0.9076 - recall: 0.9137 - accuracy: 0.9413 - val_loss: 0.0738 - val_iou: 0.9262 - val_dice_coe: 0.8452 - val_precision: 0.9048 - val_recall: 0.8098 - val_accuracy: 0.9138
# Epoch 62/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0477 - iou: 0.9523 - dice_coe: 0.8911 - precision: 0.9274 - recall: 0.9060 - accuracy: 0.9438 - val_loss: 0.0531 - val_iou: 0.9469 - val_dice_coe: 0.8796 - val_precision: 0.8996 - val_recall: 0.9012 - val_accuracy: 0.9370
# Epoch 63/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0475 - iou: 0.9525 - dice_coe: 0.8946 - precision: 0.9328 - recall: 0.9046 - accuracy: 0.9446 - val_loss: 0.0606 - val_iou: 0.9394 - val_dice_coe: 0.8676 - val_precision: 0.9318 - val_recall: 0.8300 - val_accuracy: 0.9270
# Epoch 64/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0482 - iou: 0.9518 - dice_coe: 0.8828 - precision: 0.9448 - recall: 0.8862 - accuracy: 0.9461 - val_loss: 0.0463 - val_iou: 0.9537 - val_dice_coe: 0.8963 - val_precision: 0.9174 - val_recall: 0.8987 - val_accuracy: 0.9430
# Epoch 65/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0479 - iou: 0.9521 - dice_coe: 0.8938 - precision: 0.9200 - recall: 0.9165 - accuracy: 0.9447 - val_loss: 0.0661 - val_iou: 0.9339 - val_dice_coe: 0.8739 - val_precision: 0.8211 - val_recall: 0.9711 - val_accuracy: 0.9247
# Epoch 66/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0490 - iou: 0.9510 - dice_coe: 0.8840 - precision: 0.9350 - recall: 0.8903 - accuracy: 0.9420 - val_loss: 0.0833 - val_iou: 0.9167 - val_dice_coe: 0.8464 - val_precision: 0.7895 - val_recall: 0.9424 - val_accuracy: 0.9022
# Epoch 67/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0490 - iou: 0.9510 - dice_coe: 0.8924 - precision: 0.9275 - recall: 0.9106 - accuracy: 0.9445 - val_loss: 0.0468 - val_iou: 0.9532 - val_dice_coe: 0.8939 - val_precision: 0.9367 - val_recall: 0.8935 - val_accuracy: 0.9470
# Epoch 68/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0475 - iou: 0.9525 - dice_coe: 0.8900 - precision: 0.9562 - recall: 0.8756 - accuracy: 0.9442 - val_loss: 0.0570 - val_iou: 0.9430 - val_dice_coe: 0.8714 - val_precision: 0.9546 - val_recall: 0.8226 - val_accuracy: 0.9311
# Epoch 69/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0460 - iou: 0.9540 - dice_coe: 0.8958 - precision: 0.9463 - recall: 0.8941 - accuracy: 0.9474 - val_loss: 0.0470 - val_iou: 0.9530 - val_dice_coe: 0.8964 - val_precision: 0.9481 - val_recall: 0.8755 - val_accuracy: 0.9444
# Epoch 70/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0420 - iou: 0.9580 - dice_coe: 0.9010 - precision: 0.9416 - recall: 0.9097 - accuracy: 0.9526 - val_loss: 0.0518 - val_iou: 0.9482 - val_dice_coe: 0.8869 - val_precision: 0.9655 - val_recall: 0.8381 - val_accuracy: 0.9379
# Epoch 71/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0415 - iou: 0.9585 - dice_coe: 0.8997 - precision: 0.9346 - recall: 0.9177 - accuracy: 0.9540 - val_loss: 0.0559 - val_iou: 0.9441 - val_dice_coe: 0.8789 - val_precision: 0.9517 - val_recall: 0.8489 - val_accuracy: 0.9367
# Epoch 72/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0492 - iou: 0.9508 - dice_coe: 0.8852 - precision: 0.9046 - recall: 0.9284 - accuracy: 0.9465 - val_loss: 0.0555 - val_iou: 0.9445 - val_dice_coe: 0.8775 - val_precision: 0.9571 - val_recall: 0.8489 - val_accuracy: 0.9380
# Epoch 73/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0424 - iou: 0.9576 - dice_coe: 0.9005 - precision: 0.9318 - recall: 0.9228 - accuracy: 0.9523 - val_loss: 0.0474 - val_iou: 0.9526 - val_dice_coe: 0.9019 - val_precision: 0.9528 - val_recall: 0.8793 - val_accuracy: 0.9460
# Epoch 74/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0413 - iou: 0.9587 - dice_coe: 0.9047 - precision: 0.9459 - recall: 0.9087 - accuracy: 0.9520 - val_loss: 0.0350 - val_iou: 0.9650 - val_dice_coe: 0.9210 - val_precision: 0.9278 - val_recall: 0.9457 - val_accuracy: 0.9599
# Epoch 75/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0404 - iou: 0.9596 - dice_coe: 0.9002 - precision: 0.9469 - recall: 0.9114 - accuracy: 0.9547 - val_loss: 0.0422 - val_iou: 0.9578 - val_dice_coe: 0.9077 - val_precision: 0.9006 - val_recall: 0.9489 - val_accuracy: 0.9512
# Epoch 76/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0391 - iou: 0.9609 - dice_coe: 0.9033 - precision: 0.9367 - recall: 0.9257 - accuracy: 0.9563 - val_loss: 0.0416 - val_iou: 0.9584 - val_dice_coe: 0.9017 - val_precision: 0.9343 - val_recall: 0.9151 - val_accuracy: 0.9519
# Epoch 77/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0421 - iou: 0.9579 - dice_coe: 0.9013 - precision: 0.9155 - recall: 0.9405 - accuracy: 0.9543 - val_loss: 0.0387 - val_iou: 0.9613 - val_dice_coe: 0.9103 - val_precision: 0.9500 - val_recall: 0.9034 - val_accuracy: 0.9537
# Epoch 78/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0412 - iou: 0.9588 - dice_coe: 0.9034 - precision: 0.9417 - recall: 0.9161 - accuracy: 0.9537 - val_loss: 0.0450 - val_iou: 0.9550 - val_dice_coe: 0.8982 - val_precision: 0.9543 - val_recall: 0.8830 - val_accuracy: 0.9475
# Epoch 79/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0435 - iou: 0.9565 - dice_coe: 0.9010 - precision: 0.9381 - recall: 0.9162 - accuracy: 0.9519 - val_loss: 0.0564 - val_iou: 0.9436 - val_dice_coe: 0.8709 - val_precision: 0.9676 - val_recall: 0.8076 - val_accuracy: 0.9302
# Epoch 80/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0434 - iou: 0.9566 - dice_coe: 0.8974 - precision: 0.9398 - recall: 0.9106 - accuracy: 0.9512 - val_loss: 0.0433 - val_iou: 0.9567 - val_dice_coe: 0.8995 - val_precision: 0.9616 - val_recall: 0.8636 - val_accuracy: 0.9458
# Epoch 81/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0493 - iou: 0.9507 - dice_coe: 0.8936 - precision: 0.9411 - recall: 0.8913 - accuracy: 0.9401 - val_loss: 0.0641 - val_iou: 0.9359 - val_dice_coe: 0.8650 - val_precision: 0.9060 - val_recall: 0.8514 - val_accuracy: 0.9256
# Epoch 82/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0406 - iou: 0.9594 - dice_coe: 0.9060 - precision: 0.9392 - recall: 0.9144 - accuracy: 0.9533 - val_loss: 0.0370 - val_iou: 0.9630 - val_dice_coe: 0.9129 - val_precision: 0.9270 - val_recall: 0.9338 - val_accuracy: 0.9561
# Epoch 83/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0463 - iou: 0.9537 - dice_coe: 0.8908 - precision: 0.9416 - recall: 0.8884 - accuracy: 0.9443 - val_loss: 0.0420 - val_iou: 0.9580 - val_dice_coe: 0.9071 - val_precision: 0.9072 - val_recall: 0.9459 - val_accuracy: 0.9516
# Epoch 84/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0409 - iou: 0.9591 - dice_coe: 0.8964 - precision: 0.9349 - recall: 0.9162 - accuracy: 0.9535 - val_loss: 0.0421 - val_iou: 0.9579 - val_dice_coe: 0.9030 - val_precision: 0.8946 - val_recall: 0.9644 - val_accuracy: 0.9532
# Epoch 85/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0400 - iou: 0.9600 - dice_coe: 0.9057 - precision: 0.9334 - recall: 0.9317 - accuracy: 0.9556 - val_loss: 0.0495 - val_iou: 0.9505 - val_dice_coe: 0.9008 - val_precision: 0.9255 - val_recall: 0.9029 - val_accuracy: 0.9443
# Epoch 86/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0435 - iou: 0.9565 - dice_coe: 0.8955 - precision: 0.9369 - recall: 0.9024 - accuracy: 0.9501 - val_loss: 0.0749 - val_iou: 0.9251 - val_dice_coe: 0.8589 - val_precision: 0.9470 - val_recall: 0.7964 - val_accuracy: 0.9208
# Epoch 87/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0424 - iou: 0.9576 - dice_coe: 0.9003 - precision: 0.9245 - recall: 0.9287 - accuracy: 0.9526 - val_loss: 0.1474 - val_iou: 0.8526 - val_dice_coe: 0.7440 - val_precision: 0.6650 - val_recall: 0.8591 - val_accuracy: 0.8169
# Epoch 88/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0363 - iou: 0.9637 - dice_coe: 0.9157 - precision: 0.9482 - recall: 0.9292 - accuracy: 0.9590 - val_loss: 0.0486 - val_iou: 0.9514 - val_dice_coe: 0.8985 - val_precision: 0.8713 - val_recall: 0.9707 - val_accuracy: 0.9455
# Epoch 89/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0413 - iou: 0.9587 - dice_coe: 0.8989 - precision: 0.9467 - recall: 0.9041 - accuracy: 0.9528 - val_loss: 0.0383 - val_iou: 0.9617 - val_dice_coe: 0.9125 - val_precision: 0.9094 - val_recall: 0.9577 - val_accuracy: 0.9563
# Epoch 90/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0381 - iou: 0.9619 - dice_coe: 0.9085 - precision: 0.9445 - recall: 0.9204 - accuracy: 0.9573 - val_loss: 0.0405 - val_iou: 0.9595 - val_dice_coe: 0.9073 - val_precision: 0.9053 - val_recall: 0.9544 - val_accuracy: 0.9541
# Epoch 91/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0431 - iou: 0.9569 - dice_coe: 0.9050 - precision: 0.9374 - recall: 0.9177 - accuracy: 0.9495 - val_loss: 0.0492 - val_iou: 0.9508 - val_dice_coe: 0.8916 - val_precision: 0.9651 - val_recall: 0.8463 - val_accuracy: 0.9412
# Epoch 92/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0398 - iou: 0.9602 - dice_coe: 0.9056 - precision: 0.9387 - recall: 0.9202 - accuracy: 0.9560 - val_loss: 0.0397 - val_iou: 0.9603 - val_dice_coe: 0.9083 - val_precision: 0.9636 - val_recall: 0.8765 - val_accuracy: 0.9503
# Epoch 93/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0441 - iou: 0.9559 - dice_coe: 0.8940 - precision: 0.9282 - recall: 0.9185 - accuracy: 0.9521 - val_loss: 0.0513 - val_iou: 0.9487 - val_dice_coe: 0.8905 - val_precision: 0.9316 - val_recall: 0.8691 - val_accuracy: 0.9391
# Epoch 94/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0367 - iou: 0.9633 - dice_coe: 0.9133 - precision: 0.9494 - recall: 0.9228 - accuracy: 0.9584 - val_loss: 0.0340 - val_iou: 0.9660 - val_dice_coe: 0.9178 - val_precision: 0.9424 - val_recall: 0.9284 - val_accuracy: 0.9592
# Epoch 95/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.0408 - iou: 0.9592 - dice_coe: 0.9072 - precision: 0.9489 - recall: 0.9081 - accuracy: 0.9539 - val_loss: 0.0388 - val_iou: 0.9612 - val_dice_coe: 0.9101 - val_precision: 0.9635 - val_recall: 0.8884 - val_accuracy: 0.9533
# Epoch 96/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0390 - iou: 0.9610 - dice_coe: 0.9072 - precision: 0.9486 - recall: 0.9126 - accuracy: 0.9556 - val_loss: 0.0326 - val_iou: 0.9674 - val_dice_coe: 0.9201 - val_precision: 0.9656 - val_recall: 0.9080 - val_accuracy: 0.9602
# Epoch 97/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0401 - iou: 0.9599 - dice_coe: 0.9066 - precision: 0.9401 - recall: 0.9227 - accuracy: 0.9550 - val_loss: 0.0358 - val_iou: 0.9642 - val_dice_coe: 0.9203 - val_precision: 0.9169 - val_recall: 0.9522 - val_accuracy: 0.9584
# Epoch 98/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.0430 - iou: 0.9570 - dice_coe: 0.8979 - precision: 0.9348 - recall: 0.9121 - accuracy: 0.9517 - val_loss: 0.0373 - val_iou: 0.9627 - val_dice_coe: 0.9163 - val_precision: 0.9168 - val_recall: 0.9492 - val_accuracy: 0.9570
# Epoch 99/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0417 - iou: 0.9583 - dice_coe: 0.9016 - precision: 0.9369 - recall: 0.9159 - accuracy: 0.9525 - val_loss: 0.0583 - val_iou: 0.9417 - val_dice_coe: 0.8730 - val_precision: 0.8653 - val_recall: 0.9295 - val_accuracy: 0.9324
# Epoch 100/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.0372 - iou: 0.9628 - dice_coe: 0.9162 - precision: 0.9429 - recall: 0.9331 - accuracy: 0.9570 - val_loss: 0.0394 - val_iou: 0.9606 - val_dice_coe: 0.9031 - val_precision: 0.9153 - val_recall: 0.9526 - val_accuracy: 0.9571

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_1.load_weights('unet_100_epoch.h5')

# %% [markdown]
# ![](http://)Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test.astype(np.float32), y_test.astype(np.float32), batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 20/20 [==============================] - 4s 129ms/step - loss: 0.0373 - iou: 0.9627 - dice_coe: 0.9082 - precision: 0.9251 - recall: 0.9532 - accuracy: 0.9606
# ________________________
# IOU:       |   96.36  |
# Dice Coef: |   90.89  |
# Precision: |   92.81  |
# Recall:    |   95.57  |
# Accuracy:  |   96.24  |
# Loss:      |   3.64  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 1s 111ms/step - loss: 0.0513 - iou: 0.9487 - dice_coe: 0.8857 - precision: 0.8913 - recall: 0.9486 - accuracy: 0.9488
# ________________________
# IOU:       |   94.87  |
# Dice Coef: |   88.57  |
# Precision: |   89.13  |
# Recall:    |   94.86  |
# Accuracy:  |   94.88  |
# Loss:      |   5.13  |
# ________________________
#
# -------------On validation Set---------------------
#
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0394 - iou: 0.9606 - dice_coe: 0.9031 - precision: 0.9153 - recall: 0.9526 - accuracy: 0.9571
# ________________________
# IOU:       |   96.06  |
# Dice Coef: |   90.31  |
# Precision: |   91.53  |
# Recall:    |   95.26  |
# Accuracy:  |   95.71  |
# Loss:      |   3.94  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 33
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.
